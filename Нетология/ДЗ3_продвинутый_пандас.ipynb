# %%
import pandas as pd

# %%
# Задание 1

# %%
log = pd.read_csv(r'C:\Users\operator\Documents\Python Scripts\visit_log.csv', sep=';')

# %%
log.loc[log.traffic_source.isin(['yandex', 'google']), 'source_type'] = 'organic'

# %%
log.loc[log.traffic_source.isin(['paid', 'email']) & (log.region == 'Russia'), 'source_type'] = 'ad'

# %%
log.loc[log.traffic_source.isin(['paid', 'email']) & (log.region != 'Russia'), 'source_type'] = 'other'

# %%
log.loc[log.source_type.isnull(), 'source_type'] = log.loc[log.source_type.isnull(), 'traffic_source']

# %%
log.source_type.value_counts()
# Out:
# direct     7013
# organic    5407
# ad         3790
# other      2728
# Name: source_type, dtype: int64

# %%
# Задание 2

# %%
txt = pd.read_csv(r'C:\Users\operator\Documents\Python Scripts\URLs.txt')

# %%
import re

pattern = '/\d{8}-'

# %%
txt[txt.url.str.contains(pattern)]
# Out:
#                                                   url
# 3   /politics/36188461-s-marta-zhizn-rossiyan-susc...
# 4   /world/36007585-tramp-pridumal-kak-reshit-ukra...
# 5   /science/36157853-nasa-sobiraet-ekstrennuyu-pr...
# 6   /video/36001498-poyavilis-pervye-podrobnosti-g...
# 7   /world/36007585-tramp-pridumal-kak-reshit-ukra...
# ..                                                ...
# 88  /cis/35984145-kreml-prokommentiroval-soobschen...
# 89  /video/36071019-olimpiyskie-obekty-rio-prevrat...
# 90  /science/36151301-nazvano-posledstvie-zloupotr...
# 91  /incidents/36027330-vospitatelnitsu-zatravili-...
# 92  /world/36103095-dominikanskih-zhurnalistov-ubi...
#
# [84 rows x 1 columns]

# %%
# Задание 3

# %%
rating = pd.read_csv(r'C:\Users\operator\Documents\Python Scripts\ratings.csv')

# %%
X = rating.groupby('userId').agg({'rating': ['count'], 'timestamp': ['min', 'max']}).reset_index()

# %%
X_1 = X[X.rating['count'] > 100].copy()

# %%
X_1
# Out:
#     userId rating   timestamp
#             count         min         max
# 0        1    232   964980499   965719662
# 3        4    216   945078428  1007574542
# 5        6    314   845553109   845556915
# 6        7    152  1106635416  1176181731
# 9       10    140  1455301553  1455619275
# ..     ...    ...         ...         ...
# 604    605    221  1277094764  1277177012
# 605    606   1115  1171228846  1368460577
# 606    607    187   963078392   997847387
# 607    608    831  1117161730  1189563917
# 609    610   1302  1479541963  1495959411
#
# [245 rows x 4 columns]

# %%
X_1.columns = [col[0]+'_'+col[1] for col in X_1.columns]

# %%
X_1
# Out:
#      userId_  rating_count  timestamp_min  timestamp_max
# 0          1           232      964980499      965719662
# 3          4           216      945078428     1007574542
# 5          6           314      845553109      845556915
# 6          7           152     1106635416     1176181731
# 9         10           140     1455301553     1455619275
# ..       ...           ...            ...            ...
# 604      605           221     1277094764     1277177012
# 605      606          1115     1171228846     1368460577
# 606      607           187      963078392      997847387
# 607      608           831     1117161730     1189563917
# 609      610          1302     1479541963     1495959411
#
# [245 rows x 4 columns]

# %%
X_1['lifetime'] = X_1['timestamp_max'] - X_1['timestamp_min']

# %%
print(f'{round(X_1.lifetime.mean(), 1)} секунд')
print(f' или {round(X_1.lifetime.mean() / 3600, 1)} часов')
print(f' или {round(X_1.lifetime.mean() / (3600 * 24), 1)} дня')
# Out:
# 44731367.7 секунд
#  или 12425.4 часов
#  или 517.7 дня

# %%
# Задание 4

# %%
rzd = pd.DataFrame(
    {
        'client_id': [111, 112, 113, 114, 115],
        'rzd_revenue': [1093, 2810, 10283, 5774, 981]
    }
)
rzd
# Out:
#    client_id  rzd_revenue
# 0        111         1093
# 1        112         2810
# 2        113        10283
# 3        114         5774
# 4        115          981

# %%
auto = pd.DataFrame(
    {
        'client_id': [113, 114, 115, 116, 117],
        'auto_revenue': [57483, 83, 912, 4834, 98]
    }
)
auto
# Out:
#    client_id  auto_revenue
# 0        113         57483
# 1        114            83
# 2        115           912
# 3        116          4834
# 4        117            98

# %%
air = pd.DataFrame(
    {
        'client_id': [115, 116, 117, 118],
        'air_revenue': [81, 4, 13, 173]
    }
)
air
# Out:
#    client_id  air_revenue
# 0        115           81
# 1        116            4
# 2        117           13
# 3        118          173

# %%
client_base = pd.DataFrame(
    {
        'client_id': [111, 112, 113, 114, 115, 116, 117, 118],
        'address': ['Комсомольская 4', 'Энтузиастов 8а', 'Левобережная 1а', 'Мира 14', 'ЗЖБИиДК 1', 
                    'Строителей 18', 'Панфиловская 33', 'Мастеркова 4']
    }
)
client_base
# Out:
#    client_id          address
# 0        111  Комсомольская 4
# 1        112   Энтузиастов 8а
# 2        113  Левобережная 1а
# 3        114          Мира 14
# 4        115        ЗЖБИиДК 1
# 5        116    Строителей 18
# 6        117  Панфиловская 33
# 7        118     Мастеркова 4

# %%
# таблица по типам выручки для каждого клиент id, без адреса

rzd.merge(auto, how='outer', on='client_id').merge(air, how='outer', on='client_id')
# Out:
#    client_id  rzd_revenue  auto_revenue  air_revenue
# 0        111       1093.0           NaN          NaN
# 1        112       2810.0           NaN          NaN
# 2        113      10283.0       57483.0          NaN
# 3        114       5774.0          83.0          NaN
# 4        115        981.0         912.0         81.0
# 5        116          NaN        4834.0          4.0
# 6        117          NaN          98.0         13.0
# 7        118          NaN           NaN        173.0

# %%
# таблица по типам выручки для каждого клиент id, с адресом

rzd.merge(auto, how='outer', on='client_id').merge(air, how='outer', on='client_id') \
   .merge(client_base, how='left', on='client_id')
# Out:
#    client_id  rzd_revenue  auto_revenue  air_revenue          address
# 0        111       1093.0           NaN          NaN  Комсомольская 4
# 1        112       2810.0           NaN          NaN   Энтузиастов 8а
# 2        113      10283.0       57483.0          NaN  Левобережная 1а
# 3        114       5774.0          83.0          NaN          Мира 14
# 4        115        981.0         912.0         81.0        ЗЖБИиДК 1
# 5        116          NaN        4834.0          4.0    Строителей 18
# 6        117          NaN          98.0         13.0  Панфиловская 33
# 7        118          NaN           NaN        173.0     Мастеркова 4
